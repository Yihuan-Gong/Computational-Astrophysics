# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Arithematic

# %%
data = np.loadtxt('arithmetic/advection_00000.d').transpose()
plt.plot(data[1], data[2], label='n=0')

for i in range(100, 800, 100):
    data = np.loadtxt('arithmetic/advection_00%d.d'%i).transpose()
    plt.plot(data[1], data[2], label='n=%d'%i)

plt.xlabel('x');
plt.ylabel('u(x)');
plt.title('Arithmetic method CFL=0.4')
plt.legend()

# %% [markdown]
# ### Lax-Friedrich

# %%
data = np.loadtxt('Lax-Friedrichs/advection_00000.d').transpose()
plt.plot(data[1], data[2], label='n=0')

for i in range(100, 800, 100):
    data = np.loadtxt('Lax-Friedrichs/advection_00%d.d'%i).transpose()
    plt.plot(data[1], data[2], label='n=%d'%i)

plt.xlabel('x');
plt.ylabel('u(x)');
plt.title('Lax-Friedrich CFL=0.4')
plt.legend()

# %% [markdown]
# ### Upwind

# %%
data = np.loadtxt('upwind/advection_00000.d').transpose()
plt.plot(data[1], data[2], label='n=0')

for i in range(100, 800, 100):
    data = np.loadtxt('upwind/advection_00%d.d'%i).transpose()
    plt.plot(data[1], data[2], label='n=%d'%i)

plt.xlabel('x');
plt.ylabel('u(x)');
plt.title('upwind CFL=0.4')
plt.legend()

# %% [markdown]
# ### Lax-Wendroff method

# %%
data = np.loadtxt('Lax-Wendroff/advection_00000.d').transpose()
plt.plot(data[1], data[2], label='n=0')

for i in range(100, 800, 100):
    data = np.loadtxt('Lax-Wendroff/advection_00%d.d'%i).transpose()
    plt.plot(data[1], data[2], label='n=%d'%i)

plt.xlabel('x');
plt.ylabel('u(x)');
plt.title('Lax-Wendroff CFL=0.4')
plt.legend()
